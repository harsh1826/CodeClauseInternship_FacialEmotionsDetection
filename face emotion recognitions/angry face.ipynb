# %%
import cv2

# %%
from deepface import DeepFace

# %%
img =cv2.imread('angry boy.jpg')

# %%
import matplotlib.pyplot as plot

# %%
plot.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:32<00:00,  8.07s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 75.44554471969604,
#    'disgust': 0.008866348071023822,
#    'fear': 3.2417848706245422,
#    'happy': 1.1969712562859058,
#    'sad': 11.540450900793076,
#    'surprise': 0.07155530620366335,
#    'neutral': 8.494830131530762},
#   'dominant_emotion': 'angry',
#   'region': {'x': 1637,
#    'y': 882,
#    'w': 1278,
#    'h': 1278,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 26,
#   'gender': {'Woman': 2.206217870116234, 'Man': 97.79378175735474},
#   'dominant_gender': 'Man',
#   'race': {'asian': 11.04733943939209,
#    'indian': 4.149898141622543,
#    'black': 1.2785510160028934,
#    'white': 40.059566497802734,
#    'middle eastern': 17.780523002147675,
#    'latino hispanic': 25.6841242313385},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
data_list =[{'emotion': {'angry': 75.44554471969604,
   'disgust': 0.008866348071023822,
   'fear': 3.2417848706245422,
   'happy': 1.1969712562859058,
   'sad': 11.540450900793076,
   'surprise': 0.07155530620366335,
   'neutral': 8.494830131530762},
  'dominant_emotion': 'angry',
  'region': {'x': 1637,
   'y': 882,
   'w': 1278,
   'h': 1278,
   'left_eye': None,
   'right_eye': None},
  'face_confidence': 0.92,
  'age': 26,
  'gender': {'Woman': 2.206217870116234, 'Man': 97.79378175735474},
  'dominant_gender': 'Man',
  'race': {'asian': 11.04733943939209,
   'indian': 4.149898141622543,
   'black': 1.2785510160028934,
   'white': 40.059566497802734,
   'middle eastern': 17.780523002147675,
   'latino hispanic': 25.6841242313385},
  'dominant_race': 'white'}]
face_data = data_list[0]


dominant_emotion = face_data['dominant_emotion']
print("Dominant Emotion:", dominant_emotion)
# Out:
# Dominant Emotion: angry

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


faces = faceCascade.detectMultiScale(gray, 1.1,4)


for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), ( 0, 255, 0), 2)

# %%
plot.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# Define the parameters as a dictionary
text_params = {
    'img': img,                                   # Image on which text will be inserted
    'text': predictions[0]['dominant_emotion'],   # Text to be inserted (dominant emotion)
    'org': (3000, 3000),                              # Position where text will be placed (x, y)
    'fontFace': font,                             # Font type
    'fontScale': 8,                               # Font scale
    'color': (0, 255 , 0),                         # Color of the text (BGR format)
    'thickness': 6,                               # Thickness of the text
    'lineType': cv2.LINE_4                        # Line type
}

# Use putText() method for inserting text on the image
cv2.putText(**text_params)
# Out:
# array([[[20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26],
#         ...,
#         [20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26]],
#
#        [[20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26],
#         ...,
#         [20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26]],
#
#        [[20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26],
#         ...,
#         [20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26]],
#
#        ...,
#
#        [[19, 25, 24],
#         [19, 25, 24],
#         [19, 25, 24],
#         ...,
#         [20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26]],
#
#        [[18, 24, 23],
#         [18, 24, 23],
#         [18, 24, 23],
#         ...,
#         [21, 26, 27],
#         [21, 26, 27],
#         [21, 26, 27]],
#
#        [[20, 26, 25],
#         [20, 26, 25],
#         [20, 26, 25],
#         ...,
#         [20, 25, 26],
#         [20, 25, 26],
#         [20, 25, 26]]], dtype=uint8)

# %%
plot.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plot.axis('off')
plot.show()
