# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img =cv2.imread('happy men.jpg')

# %%
import matplotlib.pyplot as plot

# %%
plot.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
 predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:58<00:00, 14.62s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 8.458814708821767e-09,
#    'disgust': 4.996001056085117e-20,
#    'fear': 1.7186228508926502e-10,
#    'happy': 99.99949336048921,
#    'sad': 4.2428337679705256e-09,
#    'surprise': 1.4696714055766145e-06,
#    'neutral': 0.0005075294514076178},
#   'dominant_emotion': 'happy',
#   'region': {'x': 2655,
#    'y': 790,
#    'w': 1579,
#    'h': 1579,
#    'left_eye': (3740, 1408),
#    'right_eye': (3172, 1378)},
#   'face_confidence': 0.95,
#   'age': 30,
#   'gender': {'Woman': 0.008524369332008064, 'Man': 99.99147653579712},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.6793211378794604e-06,
#    'indian': 1.283715041954155e-05,
#    'black': 2.7842587674062386e-07,
#    'white': 99.82765315935929,
#    'middle eastern': 0.12223773666025618,
#    'latino hispanic': 0.05009680470097391},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
data_list =[{'emotion': {'angry': 8.458814708821767e-09,
   'disgust': 4.996001056085117e-20,
   'fear': 1.7186228508926502e-10,
   'happy': 99.99949336048921,
   'sad': 4.2428337679705256e-09,
   'surprise': 1.4696714055766145e-06,
   'neutral': 0.0005075294514076178},
  'dominant_emotion': 'happy',
  'region': {'x': 2655,
   'y': 790,
   'w': 1579,
   'h': 1579,
   'left_eye': (3740, 1408),
   'right_eye': (3172, 1378)},
  'face_confidence': 0.95,
  'age': 30,
  'gender': {'Woman': 0.008524369332008064, 'Man': 99.99147653579712},
  'dominant_gender': 'Man',
  'race': {'asian': 1.6793211378794604e-06,
   'indian': 1.283715041954155e-05,
   'black': 2.7842587674062386e-07,
   'white': 99.82765315935929,
   'middle eastern': 0.12223773666025618,
   'latino hispanic': 0.05009680470097391},
  'dominant_race': 'white'}]
face_data = data_list[0]


dominant_emotion = face_data['dominant_emotion']
print("Dominant Emotion:", dominant_emotion)
# Out:
# Dominant Emotion: happy

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


faces = faceCascade.detectMultiScale(gray, 1.1,4)


for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), ( 255, 0, 0), 2)

# %%
plot.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# Define the parameters as a dictionary
text_params = {
    'img': img,                                   # Image on which text will be inserted
    'text': predictions[0]['dominant_emotion'],   # Text to be inserted (dominant emotion)
    'org': (3000, 3000),                              # Position where text will be placed (x, y)
    'fontFace': font,                             # Font type
    'fontScale': 8,                               # Font scale
    'color': (0, 0 , 255),                         # Color of the text (BGR format)
    'thickness': 6,                               # Thickness of the text
    'lineType': cv2.LINE_4                        # Line type
}

# Use putText() method for inserting text on the image
cv2.putText(**text_params)
# Out:
# array([[[135, 141, 148],
#         [135, 141, 148],
#         [136, 142, 149],
#         ...,
#         [142, 146, 147],
#         [141, 145, 146],
#         [141, 145, 146]],
#
#        [[136, 142, 149],
#         [135, 141, 148],
#         [138, 144, 151],
#         ...,
#         [143, 147, 148],
#         [142, 146, 147],
#         [140, 144, 145]],
#
#        [[137, 143, 150],
#         [135, 141, 148],
#         [138, 144, 151],
#         ...,
#         [142, 146, 147],
#         [143, 147, 148],
#         [141, 145, 146]],
#
#        ...,
#
#        [[167, 174, 177],
#         [167, 174, 177],
#         [167, 172, 175],
#         ...,
#         [128, 131, 136],
#         [127, 130, 135],
#         [129, 132, 137]],
#
#        [[166, 174, 174],
#         [167, 175, 175],
#         [168, 173, 174],
#         ...,
#         [128, 131, 136],
#         [127, 130, 135],
#         [130, 133, 138]],
#
#        [[167, 175, 175],
#         [166, 174, 174],
#         [169, 174, 175],
# ...

# %%
plot.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plot.axis('off')
plot.show()
